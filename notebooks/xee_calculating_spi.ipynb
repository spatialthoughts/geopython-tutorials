# %% [markdown]
# # Calculating Standardized Precipitation Index (SPI)
#
# One of the key advantages of the [XEE](https://github.com/google/Xee) package is the ability to use Python packages to work with data from Google Earth Engine. This package allows you to easily extract data from the vast data catalog of GEE and use widely used implementations available as Python libraries.
#
# ## Overview of the Task
#
# This notebook shows how to extract a precipitation time-series images from Earth Engine and then use the [Climate Indicies](https://climate-indices.readthedocs.io/en/latest/) Python package to calculate the Calculating Standardized Precipitation (SPI).
#
#
# **Input Layers**:
# * `ne_10m_admin_0_countries_ind.zip`: A shapefile of country boundaries
#
#
# **Output Layers**:
# *   `2024-01.tif`, `2024-02.tif` .... , `2024-12.tif` : GeoTIFF files of monthly SPI for the selected country.
#
#
# **Data Credit**:
# * Made with Natural Earth. Free vector and raster map data @ naturalearthdata.com.
# * Muñoz Sabater, J., (2019): ERA5-Land monthly averaged data from 1981 to present. Copernicus Climate Change Service (C3S) Climate Data Store (CDS). (2026-06-02), doi:10.24381/cds.68d2bb30
#
#
#
# **Running the Notebook**:
# The preferred way to run this notebook is on Google Colab.
# <a href='https://colab.research.google.com/github/spatialthoughts/geopython-tutorials/blob/main/notebooks/xee_calculating_spi.ipynb' target='_parent'><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup and Data Download
#
# The following blocks of code will install the required packages and download the datasets to your Colab environment.

# %%
# %%capture
if 'google.colab' in str(get_ipython()):
    # !pip install climate-indices xee rioxarray dask['distributed']

# %%
import climate_indices
import datetime
import ee
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os
import rioxarray as rxr
import xarray as xr
from climate_indices import indices
from xee import helpers

# %%
data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

data_url = 'https://naciscdn.org/naturalearth/10m/cultural/'


shapefile = 'ne_10m_admin_0_countries_ind.zip'

download(data_url + shapefile)
# Out:
# Downloaded data/ne_10m_admin_0_countries_ind.zip

# %% [markdown]
# ## Initialize EE and Dask Cluster

# %% [markdown]
# Initialize EE with the [High-Volume EndPoint](https://developers.google.com/earth-engine/guides/processing_environments#high-volume_endpoint) which is recommended to be used with XEE for workflows that do not use a lot of server side processing and are primarily for extracting data from stored collections. Replace the value of the `cloud_project` variable with your own project id that is linked with GEE.

# %%
cloud_project = 'spatialthoughts' # replace with your project id

try:
    ee.Initialize(
        project=cloud_project,
        opt_url='https://earthengine-highvolume.googleapis.com')
except:
    ee.Authenticate()
    ee.Initialize(
        project=cloud_project,
        opt_url='https://earthengine-highvolume.googleapis.com')

# %% [markdown]
# Setup a local Dask cluster.

# %%
from dask.distributed import Client
client = Client()  # set up local cluster on the machine
client
# Out:
# 2026-06-03T18:06:30.621196Z [info     ] To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy [distributed.http.proxy]
# 2026-06-03T18:06:30.662186Z [info     ] State start                    [distributed.scheduler]
# 2026-06-03T18:06:30.669640Z [info     ]   Scheduler at:     tcp://127.0.0.1:46649 [distributed.scheduler]
# 2026-06-03T18:06:30.670627Z [info     ]   dashboard at:  http://127.0.0.1:8787/status [distributed.scheduler]
# 2026-06-03T18:06:30.671726Z [info     ] Registering Worker plugin shuffle [distributed.scheduler]
# 2026-06-03T18:06:30.701367Z [info     ]         Start Nanny at: 'tcp://127.0.0.1:44625' [distributed.nanny]
# 2026-06-03T18:06:30.708412Z [info     ]         Start Nanny at: 'tcp://127.0.0.1:42383' [distributed.nanny]
# 2026-06-03T18:06:31.739396Z [info     ] Register worker addr: tcp://127.0.0.1:46677 name: 0 [distributed.scheduler]
# 2026-06-03T18:06:31.759998Z [info     ] Starting worker compute stream, tcp://127.0.0.1:46677 [distributed.scheduler]
# 2026-06-03T18:06:31.761978Z [info     ] Starting established connection to tcp://127.0.0.1:49000 [distributed.core]
# 2026-06-03T18:06:31.766333Z [info     ] Register worker addr: tcp://127.0.0.1:38811 name: 1 [distributed.scheduler]
# 2026-06-03T18:06:31.768334Z [info     ] Starting worker compute stream, tcp://127.0.0.1:38811 [distributed.scheduler]
# 2026-06-03T18:06:31.771080Z [info     ] Starting established connection to tcp://127.0.0.1:49002 [distributed.core]
# 2026-06-03T18:06:31.780300Z [info     ] Receive client connection: Client-f234fa12-5f76-11f1-8f0f-0242ac1c000c [distributed.scheduler]
# 2026-06-03T18:06:31.781227Z [info     ] Starting established connection to tcp://127.0.0.1:49016 [distributed.core]
# <Client: 'tcp://127.0.0.1:46649' processes=2 threads=2, memory=12.67 GiB>

# %% [markdown]
# If you are running this notebook in Colab, you will need to create and use a proxy URL to see the dashboard running on the local server.

# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import output
    port_to_expose = 8787  # This is the default port for Dask dashboard
    print(output.eval_js(f'google.colab.kernel.proxyPort({port_to_expose})'))
# Out:
# https://8787-m-s-kkb-usw1b2-1jk6xi8i3yecw-b.us-west1-2.prod.colab.dev

# %% [markdown]
# Each of our Dask workers need Earth Engine authentication. Initialize Dask workers using `ee.Initialize()`.

# %%
from dask.distributed import WorkerPlugin

class EEPlugin(WorkerPlugin):
    def __init__(self):
        pass
    def setup(self, worker):
        self.worker = worker
        try:
            ee.Initialize(
                project=cloud_project,
                opt_url='https://earthengine-highvolume.googleapis.com')
        except:
            ee.Authenticate()
            ee.Initialize(
                project=cloud_project,
                opt_url='https://earthengine-highvolume.googleapis.com')

ee_plugin = EEPlugin()
client.register_plugin(ee_plugin)
# Out:
# 2026-06-03T18:06:33.917456Z [info     ] Registering Worker plugin EEPlugin-84ccc651-0802-4531-938a-e8871bab1b64 [distributed.scheduler]
# {'tcp://127.0.0.1:38811': {'status': 'OK'},
#  'tcp://127.0.0.1:46677': {'status': 'OK'}}

# %% [markdown]
# ## Procedure

# %% [markdown]
# Load the Natural Earth Admin0 boundaries and extract the polygon for India.

# %%
shapefile_path = os.path.join(data_folder, shapefile)
gdf = gpd.read_file(shapefile_path, encoding='utf-8')
country = gdf[gdf['SOV_A3'] == 'IND']
geometry = country.geometry.union_all()

# %% [markdown]
# Now we have an ImageCollection that we want to get it as a XArray Dataset. We define the region of interest and extract the ImageCollection using the 'ee' engine.

# %%
era5 = ee.ImageCollection('ECMWF/ERA5_LAND/MONTHLY_AGGR')
filtered = era5 \
  .filter(ee.Filter.date('2000-01-01', '2025-01-01')) \
  .select('total_precipitation_sum')

# %% [markdown]
# We now read the filtered collecting using XEE. XEE requires explicit grid parameters. We extract these using the helper function [`extract_grid_params`](hhttps://xee.readthedocs.io/en/latest/_autosummary/xee.extract_grid_params.html#xee.extract_grid_params).

# %%
grid_params = helpers.extract_grid_params(filtered)
grid_params
# Out:
# {'crs': 'EPSG:4326',
#  'crs_transform': (0.1, 0, -180.05, 0, -0.1, 90.05),
#  'shape_2d': (3601, 1801)}

# %%
ds = xr.open_dataset(
    filtered,
    engine='ee',
    **grid_params,
    chunks={}
)
ds
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:                  (time: 300, y: 1801, x: 3601)
# Coordinates:
#   * time                     (time) datetime64[ns] 2kB 2000-01-01 ... 2024-12-01
#   * y                        (y) float64 14kB 90.0 89.9 89.8 ... -89.9 -90.0
#   * x                        (x) float64 29kB -180.0 -179.9 ... 179.9 180.0
# Data variables:
#     total_precipitation_sum  (time, y, x) float32 8GB dask.array<chunksize=(48, 256, 256), meta=np.ndarray>

# %% [markdown]
# Clip the pixels outside the geometry.

# %%
clipped_ds = ds \
  .rio.clip(country.geometry.values)
clipped_ds
# Out:
# <xarray.Dataset> Size: 106MB
# Dimensions:                  (time: 300, y: 302, x: 292)
# Coordinates:
#   * time                     (time) datetime64[ns] 2kB 2000-01-01 ... 2024-12-01
#   * y                        (y) float64 2kB 37.0 36.9 36.8 36.7 ... 7.1 7.0 6.9
#   * x                        (x) float64 2kB 68.2 68.3 68.4 ... 97.1 97.2 97.3
#     spatial_ref              int64 8B 0
# Data variables:
#     total_precipitation_sum  (time, y, x) float32 106MB dask.array<chunksize=(48, 238, 78), meta=np.ndarray>

# %% [markdown]
# Select the `total_precipitation_sum` variable. Many XArray functions require all the dimensions to be sorted in ascending order. Make sure `lat` and `lon` are sorted.

# %%
clipped_da = clipped_ds.total_precipitation_sum
clipped_da = clipped_da.sortby(['x', 'y'])
clipped_da = clipped_da.fillna(0.0)
# Chunk along the time dimension for efficiency
clipped_da = clipped_da.chunk(dict(time=-1))
clipped_da
# Out:
# <xarray.DataArray 'total_precipitation_sum' (time: 300, y: 302, x: 292)> Size: 106MB
# dask.array<rechunk-merge, shape=(300, 302, 292), dtype=float32, chunksize=(300, 151, 214), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 2kB 2000-01-01 2000-02-01 ... 2024-12-01
#   * y            (y) float64 2kB 6.9 7.0 7.1 7.2 7.3 ... 36.7 36.8 36.9 37.0
#   * x            (x) float64 2kB 68.2 68.3 68.4 68.5 ... 97.0 97.1 97.2 97.3
#     spatial_ref  int64 8B 0
# Attributes:
#     id:             total_precipitation_sum
#     data_type:      {'type': 'PixelType', 'precision': 'double'}
#     dimensions:     [3601, 1801]
#     crs_transform:  [0.1, 0, -180.05, 0, -0.1, 90.05]

# %% [markdown]
# We now have a monthly precipitation time-series at each pixel. We can reformat the DataArray by grouping the time-series at each lat/lon.

# %%
da_precip_groupby = clipped_da.stack(pixel=('x', 'y')).groupby('pixel')

# %% [markdown]
# Configure the SPI calculation.

# %%
scale = 3
distribution = climate_indices.indices.Distribution.gamma
data_start_year = 2000
calibration_year_initial = 2000
calibration_year_final = 2024
periodicity = climate_indices.compute.Periodicity.monthly

def calculate_spi(group):
    spi_values = climate_indices.indices.spi(
        group.values,
        scale,
        distribution,
        data_start_year,
        calibration_year_initial,
        calibration_year_final,
        periodicity
    )
    return xr.DataArray(spi_values, coords={'time': group.time}, dims=['time'])

# %%
# %%time
# apply SPI to each `pixel`
da_spi = da_precip_groupby.apply(calculate_spi)
# Out:
# 2026-06-03T18:06:52.097945Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:06:52.099622Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:06:52.103030Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:06:52.105695Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:06:52.106547Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=7.27 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:03.534639Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:03.538296Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:03.541543Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:03.544806Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:03.546849Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=8.8 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:14.413327Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:14.421675Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:14.423910Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:14.431713Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:14.433028Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=14.27 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:25.593686Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:25.597706Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:25.598797Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:25.600704Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:25.605382Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=7.92 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:37.036884Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:37.038950Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:37.044249Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:37.048033Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:37.049734Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=11.02 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:47.609756Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:47.611955Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:47.618682Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:47.622902Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:47.624812Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.1 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:07:58.978582Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:07:58.982345Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:07:58.987668Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:07:58.991180Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:07:58.996690Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=14.57 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:08:09.277722Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:08:09.279175Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:08:09.283012Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:08:09.286619Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:08:09.289432Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.48 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:08:19.929975Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:08:19.931824Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:08:19.939314Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:08:19.942603Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:08:19.946270Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=14.67 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:08:30.639553Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:08:30.646835Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:08:30.650796Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:08:30.657839Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:08:30.661739Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.15 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:08:41.625294Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:08:41.627075Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:08:41.630994Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:08:41.633505Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:08:41.635257Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=8.46 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:08:52.302741Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:08:52.307294Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:08:52.310106Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:08:52.313836Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:08:52.320000Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.97 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:03.996901Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:03.998954Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:04.006110Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:04.012291Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:04.014723Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=16.03 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:15.233751Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:15.235514Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:15.239079Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:15.243084Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:15.244745Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=9.48 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:26.056063Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:26.064129Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:26.067321Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:26.071008Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:26.073940Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=9.82 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:37.013779Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:37.017601Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:37.022267Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:37.025086Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:37.028284Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.93 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:47.062687Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:47.067569Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:47.076767Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:47.079885Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:47.082986Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.69 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:09:58.437294Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:09:58.439301Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:09:58.444785Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:09:58.447020Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:09:58.451298Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=11.91 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:10:09.303894Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:10:09.305619Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:10:09.308378Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:10:09.317259Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:10:09.320892Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.5 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:10:21.008045Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:10:21.009729Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:10:21.011154Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:10:21.021973Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:10:21.024801Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.31 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:10:31.602889Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:10:31.606478Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:10:31.609810Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:10:31.613214Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:10:31.616353Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.16 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:10:41.782227Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:10:41.783887Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:10:41.789289Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:10:41.791112Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:10:41.792328Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=8.65 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:10:52.742082Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:10:52.745873Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:10:52.747803Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:10:52.749925Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:10:52.751667Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=6.06 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:04.490821Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:04.496888Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:04.501473Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:04.506668Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:04.508790Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.14 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:15.903028Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:15.908883Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:15.911028Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:15.916304Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:15.919695Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=11.04 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:27.329548Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:27.335636Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:27.338640Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:27.344989Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:27.350696Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.31 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:38.686795Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:38.695120Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:38.698208Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:38.701748Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:38.702846Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=8.01 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:48.279982Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:48.286579Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:48.289178Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:48.292807Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:48.295528Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=9.27 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:11:58.346846Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:11:58.348310Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:11:58.357831Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:11:58.361287Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:11:58.363346Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.23 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:12:09.592993Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:12:09.596583Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:12:09.600742Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:12:09.603434Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:12:09.604320Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=7.98 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:12:19.819304Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:12:19.823814Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:12:19.827115Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:12:19.830515Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:12:19.841665Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=18.06 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:12:30.497548Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:12:30.500998Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:12:30.503691Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:12:30.507902Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:12:30.511130Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.35 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:12:41.836147Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:12:41.837799Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:12:41.843736Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:12:41.849439Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:12:41.850658Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.06 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:12:53.201875Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:12:53.207860Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:12:53.209612Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:12:53.213940Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:12:53.217339Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.97 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:04.697984Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:04.704523Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:04.706823Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:04.711161Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:04.717312Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.04 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:15.437187Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:15.449853Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:15.452994Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:15.457175Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:15.459833Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.23 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:26.188939Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:26.190817Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:26.197302Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:26.204232Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:26.206124Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.54 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:36.715170Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:36.722859Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:36.728225Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:36.736473Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:36.741459Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=18.83 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:48.128222Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:48.131842Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:48.138807Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:48.145153Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:48.154739Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=23.12 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:13:58.701281Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:13:58.706211Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:13:58.714514Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:13:58.716694Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:13:58.718558Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.61 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:14:09.480739Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:14:09.482319Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:14:09.488187Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:14:09.494738Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:14:09.499452Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=17.36 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:14:20.121333Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:14:20.129699Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:14:20.131780Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:14:20.134284Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:14:20.136371Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=8.19 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:14:30.515756Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:14:30.517238Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:14:30.519722Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:14:30.529364Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:14:30.532397Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.36 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:14:40.396914Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:14:40.401697Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:14:40.406580Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:14:40.414694Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:14:40.416446Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.11 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:14:51.664670Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:14:51.665995Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:14:51.677076Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:14:51.683089Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:14:51.686701Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=20.94 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:15:02.100725Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:15:02.102727Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:15:02.107631Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:15:02.114306Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:15:02.124255Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=21.79 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:15:13.423246Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:15:13.425289Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:15:13.430607Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:15:13.433872Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:15:13.436343Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=11.29 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:15:23.834124Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:15:23.839297Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:15:23.844529Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:15:23.847549Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:15:23.848776Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=9.72 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# ...
# 2026-06-03T18:41:02.423535Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:41:02.425166Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:41:02.430059Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:41:02.433418Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:41:02.436648Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=11.73 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:41:13.746373Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:41:13.750952Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:41:13.752549Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:41:13.755908Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:41:13.766671Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=15.96 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:41:24.746117Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:41:24.750808Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:41:24.753855Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:41:24.756507Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:41:24.757549Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=6.99 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:41:36.766726Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:41:36.768405Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:41:36.774066Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:41:36.777379Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:41:36.781911Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.82 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:41:48.908092Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:41:48.911788Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:41:48.914289Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:41:48.918801Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:41:48.921991Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.46 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:42:01.372201Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:42:01.380146Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:42:01.384389Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:42:01.392159Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:42:01.396296Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=20.64 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:42:15.134413Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:42:15.135797Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:42:15.142986Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:42:15.156047Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:42:15.157210Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=21.65 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:42:30.061541Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:42:30.062751Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:42:30.064187Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:42:30.072141Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:42:30.076722Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=14.18 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:42:41.751996Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:42:41.755145Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:42:41.760591Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:42:41.764234Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:42:41.772633Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=17.82 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:42:53.115266Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:42:53.116955Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:42:53.122836Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:42:53.127701Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:42:53.129266Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.52 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:43:06.287943Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:43:06.289298Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:43:06.295548Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:43:06.299944Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:43:06.303927Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=14.84 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:43:18.503966Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:43:18.505465Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:43:18.506840Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:43:18.521183Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:43:18.524673Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=19.41 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:43:30.974798Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:43:30.980063Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:43:30.983515Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:43:30.986306Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:43:30.992110Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=12.29 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:43:41.222565Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:43:41.227182Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:43:41.229310Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:43:41.233862Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:43:41.237155Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=10.2 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:43:52.140090Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:43:52.144093Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:43:52.145464Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:43:52.154691Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:43:52.156793Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.39 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3
# 2026-06-03T18:44:05.951319Z [info     ] calculation_started            [climate_indices.indices] distribution=gamma index_type=spi input_elements=300 input_shape=(300, 1) scale=3
# 2026-06-03T18:44:05.952878Z [info     ] distribution_transform_started [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma periodicity=monthly
# 2026-06-03T18:44:05.954760Z [info     ] distribution_fitting_started   [climate_indices.compute] calibration_period=2000-2024 distribution=gamma operation=gamma_parameters periodicity=monthly
# 2026-06-03T18:44:05.959474Z [info     ] distribution_transform_completed [climate_indices.compute] distribution=gamma input_shape='(25, 12)' operation=transform_fitted_gamma output_shape='(25, 12)' periodicity=monthly
# 2026-06-03T18:44:05.965952Z [info     ] calculation_completed          [climate_indices.indices] distribution=gamma duration_ms=13.45 index_type=spi input_elements=300 input_shape=(300, 1) output_shape=(300,) scale=3

# %% [markdown]
# Unstack the array back into original dimensions.

# %%
da_spi = da_spi.unstack('pixel')

# %% [markdown]
# ## Visualize the Results
#
# We use a faceted plot to visualize all months of a selected year.

# %%
# select a year to visualize
selected = da_spi.sel(time='2024')

legend_levels = [-3,-2,-1,0,1,2,3]
selected.plot(cmap='RdBu', col='time', col_wrap=4, levels=legend_levels)
plt.show()

# %% [markdown]
# ## Save Output as GeoTIFFs

# %% [markdown]
# We can use `rioxarray` to clip and save the resulting arrays as GeoTIFF files.

# %%
# select a year to save
selected = da_spi.sel(time='2024')

# %%
for time in selected.time.values:
    date_string = np.datetime_as_string(time, unit='M')
    image = selected.sel(time=time) \
      .rename({'lat': 'y', 'lon': 'x'}) \
      .transpose('y', 'x') \
      .rio.write_crs('EPSG:4326') \
      .rio.clip(country.geometry.values)
    output_file = f'{date_string}.tif'
    output_path = os.path.join(output_folder, output_file)
    image.rio.to_raster(output_path, driver='COG')
    print(f'Saved {output_path}')

# %% [markdown]
# ----
#
# If you want to give feedback or share your experience with this tutorial, please comment below. (requires GitHub account)
#
#
# <script src='https://utteranc.es/client.js'
#     repo='spatialthoughts/geopython-tutorials'
#     issue-term='pathname'
#     theme='github-light'
#     crossorigin='anonymous'
#     async>
# </script>
